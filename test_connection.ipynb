# %%
import pandas as pd

# %%
df = pd.read_csv('c:/Users/agyei/OneDrive/Desktop/trestle/repos/Group_3_Assignment_4_Data_Pipeline/neuce_paints/neuce_data.csv')

# %%
df.head()
# Out:
#                            company first_name last_name  phone_number  \
# 0  Boateng, Acheampong and Nkrumah     Colins    Yeboah  233573884766
# 1                     Osei-Ansomaa    Patrick      Baah  233577783341
# 2                       Asamoa Ltd      Kevin       Oti  233547625786
# 3                    Bonsu-Twumasi     Sharon    Okyere  233206649647
# 4                     Wiafe-Boakye      Jacob  Kyerewaa  233243596034
#
#                email_address  \
# 0      jessica08@example.org
# 1   twumasisusan@example.org
# 2  samakyeampong@example.org
# 3    sarahasiedu@example.org
# 4   salomeydaako@example.com
#
#                                              address   branch  \
# 0                            USS Danso\nFPO AE 50707    Accra
# 1                 3191 Ekow Lakes\nOtifort, AS 21653  Sunyani
# 2  1187 Peter River Apt. 935\nNorth Feliciaville,...     Tema
# 3          5293 Susan Village\nPort Sandra, OH 65310   Kumasi
# ...

# %%
import psycopg2
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://postgres.asetyourpassword@localhost:5432/postgres')

# %%
engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3293, in Engine.raw_connection(self)
#    3272 """Return a "raw" DBAPI connection from the connection pool.
#    3273
#    3274 The returned object is a proxied version of the DBAPI
#    (...)
#    3291
#    3292 """
# -> 3293 return self.pool.connect()
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:452, in Pool.connect(self)
#     445 """Return a DBAPI connection from the pool.
#     446
#     447 The connection is instrumented such that when its
#    (...)
# ...
